# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"BORIVALI_DWLR_REALTIME.csv")

# %%
df
# Out:
#                  timestamp  month station_id  latitude  longitude  \
# 0      2023-01-18 17:00:00      1     BOR-01     19.23      72.85
# 1      2023-01-18 18:00:00      1     BOR-01     19.23      72.85
# 2      2023-01-18 19:00:00      1     BOR-01     19.23      72.85
# 3      2023-01-18 20:00:00      1     BOR-01     19.23      72.85
# 4      2023-01-18 21:00:00      1     BOR-01     19.23      72.85
# ...                    ...    ...        ...       ...        ...
# 26275  2026-01-17 12:00:00      1     BOR-01     19.23      72.85
# 26276  2026-01-17 13:00:00      1     BOR-01     19.23      72.85
# 26277  2026-01-17 14:00:00      1     BOR-01     19.23      72.85
# 26278  2026-01-17 15:00:00      1     BOR-01     19.23      72.85
# 26279  2026-01-17 16:00:00      1     BOR-01     19.23      72.85
#
#        water_level_m  rainfall_mm  demand_mcm  aquifer_area_sqkm  \
# 0           9.006755     0.187270    0.002656                2.0
# ...
